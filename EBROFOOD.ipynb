# %%
from datetime import date
from dateutil import relativedelta

import pandas as pd

from pandas_datareader import data as pdr
import yfinance

import matplotlib.pyplot as plt
import seaborn as sns

yfinance.pdr_override()

# %%
end = date.today()
start = end - relativedelta.relativedelta(years=20)

ticker = 'EBRO.MC'
values = pdr.get_data_yahoo(ticker, start, end)[['Close']]
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
values.tail()
# Out:
#                 Close
# Date
# 2023-05-08  16.940001
# 2023-05-09  17.000000
# 2023-05-10  16.959999
# 2023-05-11  16.980000
# 2023-05-12  16.900000

# %%
values.plot(figsize=(20, 15))
plt.show()

# %%
variation = values.pct_change()*100.0
variation.tail(50).plot(subplots=True, figsize=(20, 15))
plt.show()
